# %%
# %cd /content/drive/MyDrive/final_attempt_on_bot

# !rm -rf .git
# !git init

# !git config --global user.email "achintyagupta1@gmail.com"
# !git config --global user.name "AchintyaGupta2763"

# !git checkout -b main

# Securely input your GitHub token
import getpass
token = getpass.getpass("Enter your GitHub token: ")
repo_url = f"https://{token}@github.com/AchintyaGupta2763/newClone.git"

# Add remote with token
# !git remote add origin {repo_url}

# !git add .
# !git commit -m 'files added'
# !git push -u origin main
